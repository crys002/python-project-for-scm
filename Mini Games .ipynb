# %%
import pyautogui as pg
import fontstyle
import random
def line():
    print(fontstyle.apply("___________________________________________",'red'))

print(""" __         __   ---------   __      _   ---------      --------     ------      __         __    --------   --------
|  \       /  |  ---------  /  \    | |  ---------     / / -----   /  ----  \   |  \       /  |  / /------  / /-----          
| \ \     / / |     | |     | \ \   | |     | |        | |  ____   | /    \  |  | \ \     / / |  | |        | |              
| |\ \   / /| |     | |     | |\ \  | |     | |        | | |__  \  | ------  |  | |\ \   / /| |  | |====    \ \----\           
| | \ \_/ / | |     | |     | | \ \ | |     | |        | |    | |  |  _____  |  | | \ \_/ / | |  | |         -----/ |        
| |  \___/  | |  ---------  | |  \ \| |  ---------     \ \ ---| |  | /     \ |  | |  \___/  | |  \ \-------  -----/ /         
| |         | |  ---------  | |   \___/  ---------       -------   | |     | |  | |         | |    --------  -------         
""")
line()
print(fontstyle.apply("""BY : Japit Arora(1695)
 Jappanjot Singh(1696)
 Jashan(1697)""","bold/black"))
# display number of winnings 
def scoreboard(x,y,score1,score2):
    print("""---------------------------""")
    print("""         SCOREBOARD        """)
    print("""---------------------------""")
    print("""          {} : {}          """.format(x,score1))
    print("""          {} : {}          """.format(y,score2))
    print("""---------------------------""")

p=pg.password("ENTER PASSWORD")

k=True
if p =="chitkara":
    while k:
        line()
        print(""" 1 : TIC-TAC-TOE 
 2 : STONE/PAPER/SCISSORS""")
        line()
        cho=int(input("GAME NUMBER : "))
        print()
        if cho==2:
            print( """   ---------          / /  --------------   / /    /\  /\                                                
 / /-------\ \       / /   / /-------/ /   / /     \ \/ /                                                                   
/ /         \ \     / /   / /       / /   / /       \ \/                                                                                                                                 
| |         | |    / /   / /       / /   / /       / \ \                                                                   
\ \         / /   / /   / /       / /   / /       / / \ \                                                                
 \ \-------/ /   / /   / /-------/ /   / /      /( )\ /( )\                                                             
   ---------    / /   -------------   / /       \___/ \___/                                                               
   """)
            line()
            i=int(input("No. of Games : "))
            line()
            player = 0
            computer = 0
            for m in range(i):
                n=input("Enter Stone/Paper/Scissors : ")
                list=["Stone","Paper","Scissors"]
                a=random.choice(list)
                print("Computer Choose :",a)

                if n in ["Stone",'stone','STONE']:
                    if a=="Paper":
                        computer+=1
                    elif a=="Scissors":
                        player=+1

                if n in ["Paper",'paper','PAPER']:
                    if a=="Stone":
                        player+=1
                    elif a=="Scissors":
                        computer+=1

                if n in ["Scissors","SCISSORS",'scissors']:
                    if a=="Paper":
                        player+=1
                    elif a=="Stone":
                        computer+=1
                scoreboard('Player','Computer',player,computer)

                line()
            if player>computer:
                text=fontstyle.apply("           Player Wins ","bold/green")
                print(text)
            elif computer>player:
                text=fontstyle.apply("           Computer Wins ","bold/green")
                print(text)
            else:
                text=fontstyle.apply("          Tie","bold/green")
                print(text)
        elif cho==1:
            print("""---------  ---------    -------       ---------    -----     --------        ---------   -------     -------
---------  ---------  / /------       ---------   / --- \   / /------        ---------  / /   \ \  / /------
   | |        | |     | |        ----    | |     | /   \ |  | |        ----     | |     | |   | |  | |
   | |        | |     | |        ----    | |     | ----- |  | |        ----     | |     | |   | |  | |====
   | |        | |     | |                | |     |  ___  |  | |                 | |     | |   | |  | |
   | |     ---------  \ \------          | |     | |   | |  \ \------           | |     \ \   / /  \ \------
   | |     ---------    -------          | |     | |   | |    -------           | |       -----      -------""")    
            # for differentiating parts of output , line is created
            print()
            print()
            z=int(input("ENTER NUMBER OF GAMES : "))
            x=input("1st player name (X): ")
            y=input("2nd player name (O): ")
            line()
            score1,score2=0,0
            # display elements of list 
            def display(li):
                for i in range(len(li)):
                    for j in li[i]:
                        print(j,end=' ')
                    print()
                
            # Adding "X" OR "O" in list
            
            def turn(li,a,b):
                
                line()
                print("{}'s Turn -->".format(a))
                n=int(input("Enter place ({}): ".format(b)))
                i=(n//3)
                z=n/3
                if i==z:
                    i-=1
                j=n-3*i
                if [i,j] in temp:
                    print("YOU CAN'T OVER WRITE ANY ENTRY")
                    turn(li,a,b)
                else:
                    temp.append([i,j])
                    li[i][j-1]=b
            # Checking if anyone wins the game
            def check(li):
                global ch
                global score1,score2
                player1,player2=False,False
                for i in range(3):
                    if li[i][0]==li[i][1] and li[i][0]==li[i][2]:
                        if li[i][0]=="X":
                            player1=True
                        elif li[i][0]=="O":
                            player2=True
                    elif li[0][i]==li[1][i] and li[0][i]==li[2][i]:
                        if li[0][i]=="X":
                            player1=True
                        elif li[0][i]=="O":
                            player2=True
                    elif li[0][0]==li[1][1] and li[0][0]==li[2][2]:
                        if li[0][0]=="X":
                            player1=True
                        elif li[0][0]=="O":
                            player2=True
                    elif li[0][2]==li[1][1] and li[0][2]==li[2][0]:
                        if li[0][2]=="X":
                            player1=True
                        elif li[0][2]=="O":
                            player2=True
                if player2==True:
                    line()
                    ch=True
                    score2+=1
                elif player1==True:
                    line()
                    ch=True
                    score1+=1
                else:
                    ch=False
            text = fontstyle.apply('''JIT KAMYAABI DE RAAH DI PEHLI POODI HUNDI AA 
JITAN TOH BAAD HARAN ALLE DE MIRCH TA LADDI HUNDI AA''', 'bold/Italic/blue')
            text2 = fontstyle.apply('''BRABERI DA MATLAB HAAR YA BEJJATI DA KOI ELAAN NAHI HUNDA
JE KOI BRABARI ALA MIL JAYE EHDA MATLAB DUNIYA TE KOI EKALA USTAAD NI HUNDA........''', 'bold/Italic/blue')
            # loop will continue for series of matches of desired number
            for game in range(z):
                li=[[" " for j in range(3)]for i in range(3)]
                li2=[[1,2,3],[4,5,6],[7,8,9]]
                temp=[]
                ch=False
                print("RULES -->")
                display(li2)
                for i in range(9):
                    if ch:
                        break
                    elif i%2==0:
                        turn(li,x,"X")
                        display(li)
                    elif i%2!=0:
                        turn(li,y,"O")
                        display(li)
                    check(li)
                if ch==False:
                    line()
                scoreboard(x,y,score1,score2)
            # Declaring Winner of the game
            if score1>score2:
                print(fontstyle.apply("          {} WINS           ".format(x),'bold/green'))
                print(text)
            elif score2>score1:
                print(fontstyle.apply("          {} WINS           ".format(y),'bold/green'))
                print(text)
            else:
                print(fontstyle.apply("          {}           ".format("TIE"),'bold/green'))
                print(text2)
        else:
            k=False
else:
    print("WRONG PASSWORD")
# Out:
#  __         __   ---------   __      _   ---------      --------     ------      __         __    --------   --------
# |  \       /  |  ---------  /  \    | |  ---------     / / -----   /  ----  \   |  \       /  |  / /------  / /-----
# | \ \     / / |     | |     | \ \   | |     | |        | |  ____   | /    \  |  | \ \     / / |  | |        | |
# | |\ \   / /| |     | |     | |\ \  | |     | |        | | |__  \  | ------  |  | |\ \   / /| |  | |====    \ \----\
# | | \ \_/ / | |     | |     | | \ \ | |     | |        | |    | |  |  _____  |  | | \ \_/ / | |  | |         -----/ |
# | |  \___/  | |  ---------  | |  \ \| |  ---------     \ \ ---| |  | /     \ |  | |  \___/  | |  \ \-------  -----/ /
# | |         | |  ---------  | |   \___/  ---------       -------   | |     | |  | |         | |    --------  -------
#
# ___________________________________________
# BY : Japit Arora(1695)
#  Jappanjot Singh(1696)
#  Jashan(1697)
# ___________________________________________
# ...
